# %%
simbol = [
    'IFNG',
    'IL10',
    'Tnf',
    'CSF2'
]
full_name = [
    'interferon gamma',
    'interleukin 10',
    'tumor necrosis factor',
    'colony stimulating factor 2'
]
source = [
    'HGNC: HGNC: 5438',
    'RGD: 2886',
    'MGI: MGI: 104798',
    'HGNC: HGNC: 2434'
]
gene_type = [
    'protein coding',
    'protein coding',
    'protein coding',
    'protein coding'
]
organism = [
    'homo sapiens',
    'rattus norvegicus',
    'mus musculus',
    'homo sapiens'
]
chromosome = [
    12,
    13,
    17,
    5
]

# %%
dict_pratica = {
    "simbol": simbol, 
    "full_name": full_name,
    "source": source,
    "gene_type": gene_type,
    "organism": organism,
    "chromosome": chromosome
}
dict_pratica
# Out:
# {'simbol': ['IFNG', 'IL10', 'Tnf', 'CSF2'],
#  'full_name': ['interferon gamma',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating factor 2'],
#  'source': ['HGNC: HGNC: 5438',
#   'RGD: 2886',
#   'MGI: MGI: 104798',
#   'HGNC: HGNC: 2434'],
#  'gene_type': ['protein coding',
#   'protein coding',
#   'protein coding',
#   'protein coding'],
#  'organism': ['homo sapiens',
#   'rattus norvegicus',
#   'mus musculus',
#   'homo sapiens'],
#  'chromosome': [12, 13, 17, 5]}

# %%
np.array(dict_pratica)
# Out:
# array({'simbol': ['IFNG', 'IL10', 'Tnf', 'CSF2'], 'full_name': ['interferon gamma', 'interleukin 10', 'tumor necrosis factor', 'colony stimulating factor 2'], 'source': ['HGNC: HGNC: 5438', 'RGD: 2886', 'MGI: MGI: 104798', 'HGNC: HGNC: 2434'], 'gene_type': ['protein coding', 'protein coding', 'protein coding', 'protein coding'], 'organism': ['homo sapiens', 'rattus norvegicus', 'mus musculus', 'homo sapiens'], 'chromosome': [12, 13, 17, 5]},
#       dtype=object)

# %%
gene_array = np.array(dict_pratica)
gene_array
# Out:
# array({'simbol': ['IFNG', 'IL10', 'Tnf', 'CSF2'], 'full_name': ['interferon gamma', 'interleukin 10', 'tumor necrosis factor', 'colony stimulating factor 2'], 'source': ['HGNC: HGNC: 5438', 'RGD: 2886', 'MGI: MGI: 104798', 'HGNC: HGNC: 2434'], 'gene_type': ['protein coding', 'protein coding', 'protein coding', 'protein coding'], 'organism': ['homo sapiens', 'rattus norvegicus', 'mus musculus', 'homo sapiens'], 'chromosome': [12, 13, 17, 5]},
#       dtype=object)

# %%
gene_array.shape
# Out:
# ()
