# %%
num_1 = 4
num_2 = 2
print(num_1+num_2)
print(num_1-num_2)
# Out:
# 6
# 2

# %%
tupla_1 = (1, 2, 3)
tupla_2 = (1, 20, 3)
print(tupla_1+tupla_2)
# Out:
# (1, 2, 3, 1, 20, 3)

# %%
tupla_1 += tupla_2
display(tupla_1)
display(tupla_2)
# Out:
# (1, 2, 3, 1, 20, 3)
# (1, 20, 3)

# %%
lista_da_tupla_1 = list(tupla_1)
lista_da_tupla_1
# Out:
# [1, 2, 3, 1, 20, 3]

# %%
lista_da_tupla_1[2] += 2
lista_da_tupla_1
# Out:
# [1, 2, 13, 1, 20, 3]

# %%
dict_1 = {'a': 1, 'b': 2}
dict_2 = {'a': 1, 'b': 20}
dict_1 +dict_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 dict_1 = {'a': 1, 'b': 2}
#       2 dict_2 = {'a': 1, 'b': 20}
# ----> 3 dict_1 +dict_2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
import numpy as np

# %%
array = np.array(lista_da_tupla_1)
array
# Out:
# array([ 1,  2, 13,  1, 20,  3])

# %%
array += 2
array
# Out:
# array([ 5,  6, 17,  5, 24,  7])

# %%
array *= array
array
# Out:
# array([   625,   1296,  83521,    625, 331776,   2401])

# %%
len(np.insert(arr=array, obj=2, values=100))
# Out:
# 7

# %%
array = np.array(lista_da_tupla_1).reshape(3, 2)
array
# Out:
# array([[ 1,  2],
#        [13,  1],
#        [20,  3]])

# %%
import pandas as pd

# %%
df = pd.DataFrame(array)
df
# Out:
#     0  1
# 0   1  2
# 1  13  1
# 2  20  3

# %%
array_ones = np.ones_like(df)
array_ones[1,1] = 100
array_ones
# Out:
# array([[  1,   1],
#        [  1, 100],
#        [  1,   1]])

# %%
"py" != "py"
# Out:
# False

# %%
2 <= 3 < 7
# Out:
# True

# %%
import numpy as np
import pandas as pd
