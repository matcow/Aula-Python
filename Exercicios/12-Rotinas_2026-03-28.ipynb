# %% [markdown]
# # Explicação Rotina
#
# https://1drv.ms/v/c/808ebfd9a0d86213/IQA1p5nBtUMiS4C1k70ZRFf3ASpmGVhaRHc_ibt9GJbkfww?e=9Er6z5

# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Cite três vantagens do uso das funções e duas características que toda função deva ter?

# %% [markdown]
# R.: uma vantagem do uso de funções é a possibilidade de reutilizar códigos, evitando que precise escrever a mesma coisa diversas vezes.
# maior legibilidade, uma vez que deixa o código menor e mais fácil de entender
# organização, posibilitando que problemas complexos possam sef divididos em partes menores.
#
# uma caracteristica que toda função precisa ter é a parte "def" que serve para definir sua função

# %% [markdown]
# ## Responda a pergunta do exercício 2 da aula 10, usando funções:<br>
# Instancie um objeto da classe NumPy array, contendo 5 valores quantitativos randômicos normalmente distribuídos, com média 10 e desvio padrão 3.<br><br>
# Quantos e quais são os valores superiores a 10?

# %%
import pandas as pd
import numpy as np

# %%
array_funcao =np.random.normal(10,3,5)
array_funcao
# Out:
# array([ 7.03948916,  8.7180985 , 10.00041492, 11.38647354,  8.95364676])

# %% [markdown]
# ## 02 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: usando o def vai ser definido uma função para conseguir contar os valores maiores que 10
# em seguida sera definido que serão guardados os valores maiores que 10 dentro de alguma função que eu quero contar, nesse caso são os cinco numeros com média 10 e desvio padrão 10.
#
# em seguida sera aplicado a função dentro do objeto criado, coletando os valores que são maiores que 10 e a quantidade de valores que são maiores que 10 dentro do objeto.

# %% [markdown]
# ## 03 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="./img/lista 12 1.png" width="600" />

# %% [markdown]
# ## 04 – Escreva o programa em Python:

# %%
def maiores_10(array):
    valores = [v for v in array if v > 10]
    return valores, len(valores)

valores, quantidade = maiores_10(array_funcao)

print("maiores_10:", valores)
print("quantidade:", quantidade)
# Out:
# maiores_10: [np.float64(10.000414916617759), np.float64(11.386473535819018)]
# quantidade: 2

# %% [markdown]
# ## 05 – Seria possível, com o racional proposto, saber quantos e quais valores são superiores a 20? Porque?

# %%
def maiores_10(array):
    valores = [v for v in array if v > 20]
    return valores, len(valores)

valores, quantidade = maiores_10(array_funcao)

print("maiores_10:", valores)
print("quantidade:", quantidade)
# Out:
# maiores_10: []
# quantidade: 0

# %% [markdown]
# sim. é possivel ver a quantiade de valores maiores que 20 com esse mesmo racional, mas como a média é 10 ele provavelmente não vai contar nenhum valor.
# mas se fizermos um novo array com média 20 ele vai mostrar algum numero.

# %%
array_funcao_teste =np.random.normal(20,3,5)

# %%
def maiores_10(array):
    valores = [v for v in array if v > 20]
    return valores, len(valores)

valores, quantidade = maiores_10(array_funcao_teste)

print("maiores_10:", valores)
print("quantidade:", quantidade)
# Out:
# maiores_10: [np.float64(24.38381219309999), np.float64(22.166774858262226)]
# quantidade: 2

# %% [markdown]
# ## Desenvolva um programa de computador que retorne a média de um conjunto de valores.

# %% [markdown]
# ## 06 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: somar todos os valores
# calcular a quantidade desses valores
# verificar a razão entre a soma e a quantidade
# retornar a média dessa razão.

# %% [markdown]
# ## 07 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="./img/ex 12 2.png" width="600" />

# %% [markdown]
# ## 08 – Escreva o programa em Python:

# %%
import random


def mediatron(valores):
    media = sum(valores)/len(valores)
    return media

lista_exemplo = [random.randint(1, 100) for _ in range(50)]
print(lista_exemplo)

resultados = mediatron(lista_exemplo)

print("media:", resultados)
# Out:
# [10, 3, 55, 60, 82, 40, 24, 99, 48, 36, 51, 88, 72, 81, 51, 96, 74, 73, 73, 67, 55, 2, 99, 84, 80, 89, 56, 23, 26, 31, 65, 96, 67, 98, 23, 96, 15, 33, 7, 58, 32, 79, 17, 25, 64, 96, 22, 91, 26, 30]
# media: 55.36

# %% [markdown]
# ## 09 – Desenvolva um programa de computador que retorne a divisão de dois objetos simples. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
def divitron(valores):
    a = valores [0]
    b = valores [1]
    
    print('valor:1:', a, '| tipo:', type(a))
    print('valor:2:', b, '| tipo:', type(b))

    divisao = a / b
    return divisao


exemplo = [14,7]

resultado = divitron(exemplo)

print('divisao:', resultado)
# Out:
# valor:1: 14 | tipo: <class 'int'>
# valor:2: 7 | tipo: <class 'int'>
# divisao: 2.0

# %% [markdown]
# ## 10 – Desenvolva um programa de computador que retorne a divisão de dois objetos compostos. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
def divitron_plus(valores):
    a = valores [0]
    b = valores [1]
    
    print('valor:1:', a, '| tipo:', type(a))
    print('valor:2:', b, '| tipo:', type(b))


    divisao = a / b
    return divisao


exemplo = [47.47, 23.32]

resultado = divitron(exemplo)

print('divisao:', resultado)
# Out:
# valor:1: 47.47 | tipo: <class 'float'>
# valor:2: 23.32 | tipo: <class 'float'>
# divisao: 2.035591766723842
